# %%
import pandas as pd

# %%
# Loading up the data dictionary for the IRS 990 data as drawn up at the Aspen Institute's Program
# on Philanthropy and Social Innovation Datathon.
# More info here: https://nonprofit-open-data-collective.github.io/irs-efile-master-concordance-file/

data_dict = pd.read_csv('/Users/samuelbroer/github/irs-efile-master-concordance-file/efiler_master_concordance.csv')

# %%
data_dict.shape
# Out:
# (9799, 14)

# %%
data_dict.columns
# Out:
# Index(['variable_name', 'description', 'scope', 'location_code', 'form',
#        'part', 'data_type', 'required', 'cardinality', 'rdb_table', 'xpath',
#        'version', 'production_rule', 'last_version_modified'],
#       dtype='object')

# %%
data_dict.head()
# Out:
#            variable_name                            description scope  \
# 0  AF_01_PF_ACFEADNEINNC                    Adjusted Net Income    PF
# 1  AF_01_PF_ACCOFEESAMOU               Accounting Fees - Amount    PF
# 2  AF_01_PF_ACCOFEESCATE             Accounting Fees - Category    PF
# 3  AF_01_PF_ACFEDICHPRRP  Disbursements for Charitable Purposes    PF
# 4  AF_01_PF_ACFENEININNC                  Net Investment Income    PF
#
#                    location_code          form     part data_type required  \
# 0  F990-PF-PART-01-AUX-SCHED-AFS  PF-AUX-SCHED  PART-01       NaN      NaN
# 1  F990-PF-PART-01-AUX-SCHED-AFS  PF-AUX-SCHED  PART-01       NaN      NaN
# 2  F990-PF-PART-01-AUX-SCHED-AFS  PF-AUX-SCHED  PART-01       NaN      NaN
# 3  F990-PF-PART-01-AUX-SCHED-AFS  PF-AUX-SCHED  PART-01       NaN      NaN
# 4  F990-PF-PART-01-AUX-SCHED-AFS  PF-AUX-SCHED  PART-01       NaN      NaN
#
#    cardinality  rdb_table                                              xpath  \
# 0          NaN        NaN  /Return/ReturnData/AccountingFeesSchedule/Acco...
# 1          NaN        NaN  /Return/ReturnData/AccountingFeesSchedule/Acco...
# 2          NaN        NaN  /Return/ReturnData/AccountingFeesSchedule/Acco...
# 3          NaN        NaN  /Return/ReturnData/AccountingFeesSchedule/Acco...
# 4          NaN        NaN  /Return/ReturnData/AccountingFeesSchedule/Acco...
#
#                                              version  production_rule  \
# 0  2005v3.0;2005v3.1;2005v3.2;2005v3.3;2005v4.0;2...              NaN
# 1  2004v1.0;2005v3.0;2005v3.1;2005v3.2;2005v3.3;2...              NaN
# 2  2004v1.0;2005v3.0;2005v3.1;2005v3.2;2005v3.3;2...              NaN
# 3  2005v3.0;2005v3.1;2005v3.2;2005v3.3;2005v4.0;2...              NaN
# 4  2005v3.0;2005v3.1;2005v3.2;2005v3.3;2005v4.0;2...              NaN
#
#   last_version_modified
# 0           Oct-16-2017
# 1           Oct-16-2017
# 2           Oct-16-2017
# 3           Oct-16-2017
# 4           Oct-16-2017

# %%
# The concordance says each variable code is unique, not sure what all these duplicates are

len(data_dict.variable_name.unique())
# Out:
# 6732

# %%
# Let's have a look -- what variables are repeated?

data_dict.variable_name.value_counts().head()
# Out:
# F9_16_PF_AIPANRIRNDFP     10
# F9_08_PF_ODTKEICHPEFA      8
# F9_08_PF_ODTKEICOHCFA      8
# SA_06_PZ_IRSSAPVIATLE      7
# F9_07_PZ_HCICUSADDRLN1     6
# Name: variable_name, dtype: int64

# %%
#Let's check out the most repeated one -- looks like lots of similar descriptions

data_dict[data_dict.variable_name == 'F9_16_PF_AIPANRIRNDFP'].loc[:,'description']
# Out:
# 3003    Net Rntl Incm Re Not Debt Fincd Prop - Busines...
# 3004         Excluded by section 512; 513; or 514: Amount
# 3005                       Exclusion code (01 through 41)
# 3006                    Related or exempt function income
# 3007        Net Rntl Incm Re Not Debt Fincd Prop - Amount
# 3074    Net Rntl Incm Re Not Debt Fincd Prop - Busines...
# 3075         Excluded by section 512; 513; or 514: Amount
# 3076                       Exclusion code (01 through 43)
# 3077                    Related or exempt function income
# 3078        Net Rntl Incm Re Not Debt Fincd Prop - Amount
# Name: description, dtype: object

# %%
#I'll come back to those later -- for now let's see what variables I actually want to use

data_dict.scope.unique()
# Out:
# array(['PF', 'EZ', 'PC', 'PZ', 'SG', 'HD'], dtype=object)

# %%
# To get started I'm only gonna look at PZ fields, since they will have most of what we're
# after for the most organizations. See concordance
    
PZ_dict = data_dict[data_dict.scope == 'PZ']

# %%
# Let's look at the different forms we have here

PZ_dict.form.unique()
# Out:
# array(['F990', 'SCHED-A', 'SCHED-B', 'SCHED-C', 'SCHED-E', 'SCHED-G',
#        'SCHED-L', 'SCHED-N', 'SCHED-O'], dtype=object)

# %%
# Again to start off we'll take 990 fields to get up and running

PZ_990_dict = PZ_dict[PZ_dict.form == 'F990']

# %%
#Now let's check back in on those repeated variables

print(PZ_990_dict.shape)
len(PZ_990_dict.variable_name.unique())
# Out:
# (590, 3)
# 229

# %%
# Let's have a look

PZ_990_dict.variable_name.value_counts().head()
# Out:
# F9_03_PZ_PGMSVCGRANTS       6
# F9_07_PZ_HCICUSADDRCITY     6
# F9_06_PZ_RECPERSADDL2       6
# F9_06_PZ_RECPERSADDST       6
# F9_06_PZ_RECPERSADDFCTRY    6
# Name: variable_name, dtype: int64

# %%
PZ_990_dict[PZ_990_dict.variable_name == 'F9_03_PZ_PGMSVCGRANTS'].loc[:,'description']
# Out:
# 173    Program Accomplishment Grants
# 174    Program Accomplishment Grants
# 175    Program Accomplishment Grants
# 176    Program Accomplishment Grants
# 177    Program Accomplishment Grants
# 178    Program Accomplishment Grants
# Name: description, dtype: object

# %%
# Looks like fields with identical descriptions, maybe different xpaths?
# For the purposes of the data dictionary we can drop them

PZ_990_dict.drop_duplicates('variable_name', inplace=True)
PZ_990_dict.reset_index(drop=True, inplace=True)
print(PZ_990_dict.shape)
PZ_990_dict.head()
# Out:
# (229, 3)
#             variable_name                                 description  \
# 0  F9_00_PZ_ADDRADDRLINE1  Address of Filing Organization (US Line 1)
# 1   F9_00_PZ_ADDRESCITYIT    Address of Filing Organization (US City)
# 2  F9_00_PZ_ADDRESSCHANGE   Indicates this form has an address change
# 3   F9_00_PZ_ADDRESSTATET   Address of Filing Organization (US State)
# 4   F9_00_PZ_ADDRSTATABBR   Address of Filing Organization (US State)
#
#                location_code
# 0                   F990-EZ-
# 1                   F990-EZ-
# 2  F990-PC-PART-00-SECTION-B
# 3                   F990-EZ-
# 4                   F990-EZ-

# %%
#So what meta-info have we got for these variables?

PZ_990_dict.columns
# Out:
# Index(['variable_name', 'description', 'scope', 'location_code', 'form',
#        'part', 'data_type', 'required', 'cardinality', 'rdb_table', 'xpath',
#        'version', 'production_rule', 'last_version_modified'],
#       dtype='object')

# %%
# Let's clean up by dropping columns we don't care about and/or are incomplete according to the concordance

PZ_990_dict = PZ_990_dict[['variable_name', 'description', 'location_code']]

# %%
PZ_990_dict.head()
# Out:
#                 variable_name  \
# 359     F9_06_PZ_ACTNOTPRERPT
# 361  F9_03_PZ_PGMSVCACTIVITY2
# 363    F9_03_PZ_PGMSVCGRANTS2
# 366  F9_03_PZ_PGMSVCACTIVITY3
# 368    F9_03_PZ_PGMSVCGRANTS3
#
#                                            description  \
# 359  Did the organization engage in any activity no...
# 361                 Program Accomplishment Description
# 363                      Program Accomplishment Grants
# 366                 Program Accomplishment Description
# 368                      Program Accomplishment Grants
#
#                   location_code
# 359     F990-PC-PART-06-LINE-76
# 361  F990-PC-PART-03-LINE-4A-4C
# 363     F990-PC-PART-03-LINE-4B
# 366  F990-PC-PART-03-LINE-4A-4C
# 368     F990-PC-PART-03-LINE-4C

# %%
# Let's make it a bit nicer to look at

PZ_990_dict.sort_values('variable_name', inplace = True)
PZ_990_dict.reset_index(drop=True, inplace=True)

# %%
# Much better

PZ_990_dict.head()
# Out:
#             variable_name                                 description  \
# 0  F9_00_PZ_ADDRADDRLINE1  Address of Filing Organization (US Line 1)
# 1   F9_00_PZ_ADDRESCITYIT    Address of Filing Organization (US City)
# 2  F9_00_PZ_ADDRESSCHANGE   Indicates this form has an address change
# 3   F9_00_PZ_ADDRESSTATET   Address of Filing Organization (US State)
# 4   F9_00_PZ_ADDRSTATABBR   Address of Filing Organization (US State)
#
#                location_code
# 0                   F990-EZ-
# 1                   F990-EZ-
# 2  F990-PC-PART-00-SECTION-B
# 3                   F990-EZ-
# 4                   F990-EZ-

# %%
# Gotta sort through these to pull the fields we're gonna want, so let's create a new dataframe to hold onto those

final_PZ_990_dict = pd.DataFrame()

# %%
# Started adding ones I wanted when I realized it would probably be better to work from the actual fields from
# the data on Athena and working back rather than going by the concordance dictionary

final_PZ_990_dict = final_data_dict.append(data_dict.loc[209])
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
# Just went through 50 at a time picking out the ones I want -- waste of time though

PZ_990_dict.iloc[200:250]

# %%
#Queried for unique variables under the PZ scope from Athena. Looks like there weren't as many as in the data dict

pz_vars_actual = pd.read_csv('/Users/samuelbroer/ds/Metis/Project_5_Kojack/pz_view_test_unique_vars.csv')
print(pz_vars_actual.shape)
pz_vars_actual.info()
# Out:
# (141, 1)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141 entries, 0 to 140
# Data columns (total 1 columns):
# variable    141 non-null object
# dtypes: object(1)
# memory usage: 1.2+ KB

# %%
#So let's match up the actual variables from Athena with their description from the data dictionary

pz_dict_actual = pz_vars_actual.merge(PZ_990_dict, how='left', left_on='variable',
                                      right_on='variable_name', validate='1:1').drop('variable_name', axis=1)
pz_dict_actual.head()
# Out:
#                     variable  \
# 0          F9_01_PZ_TOTLIABS
# 1      F9_03_PZ_PGMSVCGRANTS
# 2       F9_01_PZ_SALCOMPBENS
# 3     F9_06_PZ_TAIMUNIRRCC12
# 4  F9_07_PZ_HCICFORADDRSTATE
#
#                                          description  \
# 0                             Total Liabilities, BOY
# 1                      Program Accomplishment Grants
# 2                                 Salaries, etc - PY
# 3  501(c)(3) Organizations: Amount of tax imposed...
# 4  Highest compensated independent contractor (to...
#
#                              location_code
# 0                  F990-PC-PART-01-LINE-21
# 1                  F990-PC-PART-03-LINE-4D
# 2                  F990-PC-PART-01-LINE-15
# 3                                 F990-EZ-
# 4  F990-PC-PART-07-SECTION-B-LINE-01-COL-A

# %%
#Let's get it sorted by variable to make it easier to sift through

pz_dict_actual = pz_dict_actual.sort_values('variable').reset_index(drop=True)
pz_dict_actual.head()
# Out:
#                  variable                                description  \
# 0  F9_00_PZ_ADDRESSCHANGE  Indicates this form has an address change
# 1    F9_00_PZ_AMENDRETURN   Inidcates this form is an amended return
# 2   F9_00_PZ_EXEMPT4947A1        Indicates a 4947(a)(1) organization
# 3     F9_00_PZ_EXEMPT501C            Indicates a 501(c) organization
# 4    F9_00_PZ_EXEMPT501C3         Indicates a 501(c)(3) organization
#
#                location_code
# 0  F990-PC-PART-00-SECTION-B
# 1  F990-EZ-PART-00-SECTION-B
# 2  F990-EZ-PART-00-SECTION-J
# 3  F990-PC-PART-00-SECTION-I
# 4  F990-EZ-PART-00-SECTION-J

# %%
#Alrighty and now the same process as before, create a new dataframe and add the variables we want to keep as we go

pz_dict_final = pd.DataFrame()

# %%
# Slices added: 11, 16:24, 26:39, 43, 119
# Slices added 2: 11, 15:22, 24:36, 40, 116, 117, 123:134, 136:140
pz_dict_final = pz_dict_final.append(pz_dict_actual.loc[136:140])
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
pz_dict_actual.loc[100:150]
# Out:
#                       variable  \
# 100     F9_06_PZ_TAIMUNIRRCC55
# 101      F9_07_PC_CCCAASABBREV
# 102    F9_07_PZ_HCICBUSNAMELN1
# 103    F9_07_PZ_HCICBUSNAMELN2
# 104  F9_07_PZ_HCICCOMPENSATION
# 105   F9_07_PZ_HCICFORADDRCITY
# 106   F9_07_PZ_HCICFORADDRCTRY
# 107    F9_07_PZ_HCICFORADDRLN1
# 108  F9_07_PZ_HCICFORADDRSTATE
# 109    F9_07_PZ_HCICFORADDRZIP
# 110    F9_07_PZ_HCICPERSONNAME
# 111      F9_07_PZ_HCICSERVICES
# 112    F9_07_PZ_HCICUSADDRCITY
# 113     F9_07_PZ_HCICUSADDRLN1
# 114     F9_07_PZ_HCICUSADDRLN2
# 115     F9_07_PZ_HCICUSADDRZIP
# 116         F9_07_PZ_OFDIR1A1D
# 117         F9_07_PZ_OFDIR1A1E
# 118         F9_07_PZ_OFDIR1A1F
# 119        F9_07_PZ_OFDIR1A1LA
# 120        F9_07_PZ_OFDIR1A1UA
# 121        F9_07_PZ_OFDIR1A1UB
# 122            F9_07_PZ_SCHEDO
# 123      F9_08_PZ_COSTGOODSOLD
# 124      F9_08_PZ_FUNDGROSINCO
# 125    F9_08_PZ_GAMINGGROSSINC
# 126      F9_08_PZ_GROSSALEINVE
# 127      F9_08_PZ_INVINCTOTREV
# 128           F9_08_PZ_MEMDUES
# 129      F9_10_PZ_NETASSETSBOY
# 130      F9_10_PZ_NETASSETSEOY
# 131   F9_10_PZ_NETLANDBUILDBOY
# 132   F9_10_PZ_NETLANDBUILDEOY
# 133    F9_10_PZ_OTHERASSETSBOY
# 134    F9_10_PZ_OTHERASSETSEOY
# 135       F9_10_PZ_SCHEDONOTES
# 136    F9_10_PZ_TOTALASSETSBOY
# 137    F9_10_PZ_TOTALASSETSEOY
# 138     F9_10_PZ_TOTALLIABSBOY
# 139     F9_10_PZ_TOTALLIABSEOY
# 140      F9_11_PZ_OTCHINNEASSS
#
#                                            description  \
# 100  501(c)(3) Organizations: Amount of tax imposed...
# 101  Highest compensated independent contractor (to...
# 102  Highest compensated independent contractor (to...
# 103  Highest compensated independent contractor (to...
# 104  Highest compensated independent contractor (to...
# 105  Highest compensated independent contractor (to...
# 106  Highest compensated independent contractor (to...
# 107  Highest compensated independent contractor (to...
# 108  Highest compensated independent contractor (to...
# 109  Highest compensated independent contractor (to...
# 110  Highest compensated independent contractor (to...
# 111  Highest compensated independent contractor (to...
# 112  Highest compensated independent contractor (to...
# 113  Highest compensated independent contractor (to...
# 114  Highest compensated independent contractor (to...
# 115  Highest compensated independent contractor (to...
# 116          Reportable compensation from organization
# 117  Reportable compensation from related organizat...
# 118                                 Other compensation
# 119                                              Title
# 120                                      Name - Person
# 121                             Average hours per week
# 122  Schedule O contains a response to a question i...
# 123                            Less cost of goods sold
# 124                                      IRS990 - 8a-1
# 125                Gross income from gaming activities
# 126                           gross sales of inventory
# 127                                      Invest income
# 128                                    Membership Dues
# 129     Net assets or fund balances, beginning of year
# 130           Net assets or fund balances, end of year
# 131  Net value including lands, buildings, and equi...
# 132  Net value including lands, buildings, and equi...
# 133                    Other assets, beginning of year
# 134                          Other assets, end of year
# 135  Schedule O contains a response to a question i...
# 136                    Total assets, beginning of year
# 137                          Total assets, end of year
# 138               Total liabilities, beginning of year
# 139                     Total liabilities, end of year
# 140       Other changes in net assets or fund balances
#
#                                location_code
# 100                                 F990-EZ-
# 101            F990-EZ-PART-06-LINE-51-COL-A
# 102  F990-PC-PART-07-SECTION-B-LINE-01-COL-A
# 103            F990-EZ-PART-06-LINE-51-COL-A
# 104            F990-EZ-PART-06-LINE-51-COL-C
# 105            F990-EZ-PART-06-LINE-51-COL-A
# 106  F990-PC-PART-07-SECTION-B-LINE-01-COL-A
# 107  F990-PC-PART-07-SECTION-B-LINE-01-COL-A
# 108  F990-PC-PART-07-SECTION-B-LINE-01-COL-A
# 109  F990-PC-PART-07-SECTION-B-LINE-01-COL-A
# 110            F990-EZ-PART-06-LINE-51-COL-A
# 111  F990-PC-PART-07-SECTION-B-LINE-01-COL-B
# 112            F990-EZ-PART-06-LINE-51-COL-A
# 113  F990-PC-PART-07-SECTION-B-LINE-01-COL-A
# 114  F990-PC-PART-07-SECTION-B-LINE-01-COL-A
# 115            F990-EZ-PART-06-LINE-51-COL-A
# 116           F990-PC-PART-07-LINE-1a1-COL-D
# 117           F990-PC-PART-07-LINE-1a1-COL-E
# 118           F990-PC-PART-07-LINE-1a1-COL-F
# 119        F990-PC-PART-07-LINE-1a1low-COL-A
# 120                  F990-EZ-PART-04-LINE-1a
# 121             F990-EZ-PART-04-LINE-1-COL-B
# 122                  F990-PC-PART-07-LINE-00
# 123                                 F990-EZ-
# 124                                 F990-EZ-
# 125                  F990-EZ-PART-01-LINE-6A
# 126                                 F990-EZ-
# 127                  F990-EZ-PART-01-LINE-04
# 128                 F990-PC-PART-08-LINE-01B
# 129              F990-PC-PART-10-LINE-33-BOY
# 130              F990-EZ-PART-02-LINE-27-EOY
# 131              F990-EZ-PART-02-LINE-23-BOY
# 132             F990-PC-PART-10-LINE-10C-EOY
# 133              F990-EZ-PART-02-LINE-24-BOY
# 134              F990-PC-PART-10-LINE-15-EOY
# 135                F990-PC-PART-10-LINE-00-1
# 136              F990-PC-PART-10-LINE-16-BOY
# 137              F990-PC-PART-10-LINE-16-EOY
# 138              F990-PC-PART-10-LINE-26-BOY
# 139              F990-PC-PART-10-LINE-26-EOY
# 140                                 F990-EZ-

# %%
pz_dict_final.reset_index(drop=True, inplace=True)
pz_dict_final.head()
# Out:
#                        description               location_code  \
# 0          Gross Receipts (Header)   F990-EZ-PART-00-SECTION-L
# 1    Benefits paid to members - CY     F990-PC-PART-01-LINE-14
# 2         Less: cost of goods sold                    F990-EZ-
# 3                Excess or deficit                    F990-EZ-
# 4  Grants and similar amounts - CY  F990-PC-PART-01-LINE-13-CY
#
#                   variable
# 0   F9_00_PZ_GROSSRECEIPTS
# 1  F9_01_PZ_BENSPDTOMEMSCY
# 2    F9_01_PZ_COSTGOODSOLD
# 3    F9_01_PZ_EXCDEFFORYEA
# 4     F9_01_PZ_GRNTSPAIDCY

# %%
pz_dict_final.to_csv('data_dict_2.csv')

# %%
# Manually built dictionary for converting variable names to better column names

column_name_dict_2 = {
    'F9_00_PZ_GROSSRECEIPTS' : 'Gross_Receipts',
    'F9_01_PZ_BENSPDTOMEMSCY' : 'Exp_Benefits_to_Members',
    'F9_01_PZ_COSTGOODSOLD' : 'Cost_of_Goods_Sold',
    'F9_01_PZ_EXCDEFFORYEA' : 'Excess_Deficit_1',
    'F9_01_PZ_GRNTSPAIDCY' : 'Grants_Paid',
    'F9_01_PZ_GRPRLOSAINNV' : 'Inventory_Sales',
    'F9_01_PZ_INVESTMTINCCY' : 'Investment_Income',
    'F9_01_PZ_ISANREFRGAAM' : 'Rev_Special_Events',
    'F9_01_PZ_NAFBBOY' : 'Net_Assets_BOY',
    'F9_01_PZ_NETASSFNDBALEOY' : 'Net_Asset_EOY',
    'F9_01_PZ_OTCHINNEASSS' : 'Change_in_Assets_Other',
    'F9_01_PZ_OTHEXPSCY' : 'Other_Expenses',
    'F9_01_PZ_OTHREVCY' : 'Other_Revenue',
    'F9_01_PZ_PROGSERREVCY' : 'Program_Service_Rev',
    'F9_01_PZ_REVSLESSEXPSCY' : 'Excess_Deficit_2',
    'F9_01_PZ_SALCOMPBENS' : 'Employee_Comp_1',
    'F9_01_PZ_SALCOMPBENSCY' : 'Employee_Comp_2',
    'F9_01_PZ_SPEEVEDIREXP' : 'Special_Events_Exp',
    'F9_01_PZ_SPEEVEGROREV' : 'Special_Events_Rev',
    'F9_01_PZ_SPEVNEINLOOS' : 'Special_Events_Net',
    'F9_01_PZ_TOTASSETSBOY' : 'Total_Assets_BOY',
    'F9_01_PZ_TOTEXPSCY' : 'Total_Exp',
    'F9_01_PZ_TOTLIABS' : 'Total_Liabilities',
    'F9_01_PZ_TOTREVCY' : 'Total_Rev',
    'F9_03_PZ_OTHREVTOT' : 'Other_Rev',
    'F9_07_PZ_OFDIR1A1D' : 'Director_Compensation',
    'F9_08_PZ_COSTGOODSOLD' : 'Cost_of_Goods_Sold_2',
    'F9_08_PZ_FUNDGROSINCO' : 'Fundraising_Costs',
    'F9_08_PZ_GAMINGGROSSINC' : 'Rev_Special_Events_2',
    'F9_08_PZ_GROSSALEINVE' : 'Inventory_Sales_2',
    'F9_08_PZ_INVINCTOTREV' : 'Investment_Income_2',
    'F9_08_PZ_MEMDUES' : 'Membership_Dues',
    'F9_10_PZ_NETASSETSBOY' : 'Net_Assets_BOY_2',
    'F9_10_PZ_NETASSETSEOY' : 'Net_Assets_EOY_2',
    'F9_10_PZ_NETLANDBUILDBOY' : 'Net_Value_BOY',
    'F9_10_PZ_NETLANDBUILDEOY' : 'Net_Value_EOY',
    'F9_10_PZ_OTHERASSETSBOY' : 'Other_Assets_BOY',
    'F9_10_PZ_OTHERASSETSEOY' : 'Other_Assets_EOY',
    'F9_10_PZ_TOTALASSETSBOY' : 'Total_Assets_BOY_2',
    'F9_10_PZ_TOTALASSETSEOY' : 'Total_Assets_EOY',
    'F9_10_PZ_TOTALLIABSBOY' : 'Total_Liabilities_BOY',
    'F9_10_PZ_TOTALLIABSEOY' : 'Total_Liabilities_EOY',
    'F9_11_PZ_OTCHINNEASSS' : 'Change_in_Assets_Other_2' 
}

# %%
pz_dict_final
# Out:
#                                           description  \
# 0                             Gross Receipts (Header)
# 1                       Benefits paid to members - CY
# 2                            Less: cost of goods sold
# 3                                   Excess or deficit
# 4                     Grants and similar amounts - CY
# 5      Gross profit (or loss) from sales of inventory
# 6                    Investment income - current year
# 7                    Net Assets or Fund Balances; BOY
# 8                    Net Assets or Fund Balances, EOY
# 9                         Other changes in net assets
# 10                        Other expenses - total - CY
# 11                       Other revenue - current year
# 12                              ProgramServiceRevenue
# 13                             Excess or deficit - CY
# 14                                 Salaries, etc - PY
# 15  Salaries, other compensation, and employee ben...
# 16                     Special events direct expenses
# 17                Special events net income (or loss)
# 18                                  Total Assets, BOY
# 19                                Total Expenses - CY
# 20                             Total Liabilities, BOY
# 21                                 Total revenue - CY
# 22                              Other revenue - total
# 23  Reportable compensation from related organizat...
# 24                            Less cost of goods sold
# 25                                      IRS990 - 8a-1
# 26                Gross income from gaming activities
# 27                           gross sales of inventory
# 28                                      Invest income
# 29                                    Membership Dues
# 30     Net assets or fund balances, beginning of year
# 31           Net assets or fund balances, end of year
# 32  Net value including lands, buildings, and equi...
# 33  Net value including lands, buildings, and equi...
# 34                    Other assets, beginning of year
# 35                          Other assets, end of year
# 36                    Total assets, beginning of year
# 37                          Total assets, end of year
# 38               Total liabilities, beginning of year
# 39                     Total liabilities, end of year
# 40       Other changes in net assets or fund balances
#
#                      location_code                  variable
# 0        F990-EZ-PART-00-SECTION-L    F9_00_PZ_GROSSRECEIPTS
# 1          F990-PC-PART-01-LINE-14   F9_01_PZ_BENSPDTOMEMSCY
# 2                         F990-EZ-     F9_01_PZ_COSTGOODSOLD
# 3                         F990-EZ-     F9_01_PZ_EXCDEFFORYEA
# 4       F990-PC-PART-01-LINE-13-CY      F9_01_PZ_GRNTSPAIDCY
# 5         F990-PC-PART-01-LINE-10c     F9_01_PZ_GRPRLOSAINNV
# 6       F990-PC-PART-01-LINE-10-CY    F9_01_PZ_INVESTMTINCCY
# 7                         F990-EZ-          F9_01_PZ_NAFBBOY
# 8          F990-PC-PART-01-LINE-22  F9_01_PZ_NETASSFNDBALEOY
# 9                         F990-EZ-     F9_01_PZ_OTCHINNEASSS
# 10         F990-EZ-PART-01-LINE-16        F9_01_PZ_OTHEXPSCY
# 11         F990-PC-PART-01-LINE-11         F9_01_PZ_OTHREVCY
# 12         F990-EZ-PART-01-LINE-02     F9_01_PZ_PROGSERREVCY
# 13         F990-PC-PART-01-LINE-18   F9_01_PZ_REVSLESSEXPSCY
# 14         F990-PC-PART-01-LINE-15      F9_01_PZ_SALCOMPBENS
# 15         F990-EZ-PART-01-LINE-12    F9_01_PZ_SALCOMPBENSCY
# 16                        F990-EZ-     F9_01_PZ_SPEEVEDIREXP
# 17         F990-PC-PART-01-LINE-9c     F9_01_PZ_SPEVNEINLOOS
# 18         F990-PC-PART-01-LINE-20     F9_01_PZ_TOTASSETSBOY
# 19         F990-PC-PART-01-LINE-18        F9_01_PZ_TOTEXPSCY
# 20         F990-PC-PART-01-LINE-21         F9_01_PZ_TOTLIABS
# 21          F990-EZ-PART-01-LINE-9         F9_01_PZ_TOTREVCY
# 22         F990-EZ-PART-01-LINE-08        F9_03_PZ_OTHREVTOT
# 23  F990-PC-PART-07-LINE-1a1-COL-E        F9_07_PZ_OFDIR1A1E
# 24                        F990-EZ-     F9_08_PZ_COSTGOODSOLD
# 25                        F990-EZ-     F9_08_PZ_FUNDGROSINCO
# 26         F990-EZ-PART-01-LINE-6A   F9_08_PZ_GAMINGGROSSINC
# 27                        F990-EZ-     F9_08_PZ_GROSSALEINVE
# 28         F990-EZ-PART-01-LINE-04     F9_08_PZ_INVINCTOTREV
# 29        F990-PC-PART-08-LINE-01B          F9_08_PZ_MEMDUES
# 30     F990-PC-PART-10-LINE-33-BOY     F9_10_PZ_NETASSETSBOY
# 31     F990-EZ-PART-02-LINE-27-EOY     F9_10_PZ_NETASSETSEOY
# 32     F990-EZ-PART-02-LINE-23-BOY  F9_10_PZ_NETLANDBUILDBOY
# 33    F990-PC-PART-10-LINE-10C-EOY  F9_10_PZ_NETLANDBUILDEOY
# 34     F990-EZ-PART-02-LINE-24-BOY   F9_10_PZ_OTHERASSETSBOY
# 35     F990-PC-PART-10-LINE-15-EOY   F9_10_PZ_OTHERASSETSEOY
# 36     F990-PC-PART-10-LINE-16-BOY   F9_10_PZ_TOTALASSETSBOY
# 37     F990-PC-PART-10-LINE-16-EOY   F9_10_PZ_TOTALASSETSEOY
# 38     F990-PC-PART-10-LINE-26-BOY    F9_10_PZ_TOTALLIABSBOY
# 39     F990-PC-PART-10-LINE-26-EOY    F9_10_PZ_TOTALLIABSEOY
# 40                        F990-EZ-     F9_11_PZ_OTCHINNEASSS

# %%
import pickle

with open('name_mapper_2.pkl', 'wb') as picklefile:
    pickle.dump(column_name_dict_2, picklefile)
